# %% [markdown]
# # Data Visualisation

# %%
from __future__ import division

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %%
train_ds = "mushroom_train.csv"
test_ds = "mushroom_test.csv"
data = pd.read_csv(test_ds)

# %%
def plot(x_values = [], y_values = [], x_label = "", y_label = "", plot_label = ""):
    # Plot of Value of gain with number of iterations
    fig = plt.figure();
    ax = fig.add_subplot(111);

    if (x_values == []):
        print "True"
        line, = ax.plot(y_values,  lw=2)
    else: 
        line, = ax.plot(x_values, y_values,  lw=2)

    ax.set_title(plot_label)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    plt.show()
    plt.close()
    return

# %%
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         f           s         e       f    s               f
# 1     p         x           y         w       t    p               f
# 2     e         f           s         n       t    n               f
# 3     p         x           s         e       f    y               f
# 4     e         x           s         w       t    l               f
#
#   gill-spacing gill-size gill-color   ...    stalk-color-above-ring  \
# 0            c         n          b   ...                         p
# 1            c         n          k   ...                         w
# 2            c         b          e   ...                         e
# 3            c         n          b   ...                         p
# 4            c         b          n   ...                         w
#
#   stalk-color-below-ring  veil-type veil-color weight ring-number ring-type  \
# ...

# %% [markdown]
# # Data preprocessing

# %%
data = data.replace({'?': np.NaN}, regex=False);

# %% [markdown]
# ### Missing value ratio filter

# %%
data = data.dropna(thresh=0.7*len(data), axis=1)
data.shape
# Out:
# (5686, 24)

# %% [markdown]
# ### PCA

# %%
pd.get_dummies(data).shape
#pca = PCA(n_components=5)
#pca.fit(pd.get_dummies(data))
data.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           f         g       t    n               f            c
# 1         x           y         g       f    f               f            c
# 2         b           s         w       t    a               f            c
# 3         f           y         y       f    f               f            c
# 4         b           y         y       t    a               f            c
#
#   gill-size gill-color stalk-shape   ...   stalk-color-above-ring  \
# 0         b          u           t   ...                        p
# 1         b          g           e   ...                        b
# 2         b          w           e   ...                        w
# 3         b          p           e   ...                        n
# 4         b          w           e   ...                        w
#
#    stalk-color-below-ring veil-type veil-color weight ring-number ring-type  \
# ...

# %%
pd.get_dummies(data).shape
#pca = PCA(n_components=5)
#pca.fit(pd.get_dummies(data))
data.head
# Out:
# <bound method DataFrame.head of      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         f           s         e       f    s               f
# 1        p         x           y         w       t    p               f
# 2        e         f           s         n       t    n               f
# 3        p         x           s         e       f    y               f
# 4        e         x           s         w       t    l               f
# 5        p         x           f         y       f    f               f
# 6        e         f           s         g       f    n               f
# 7        e         f           f         n       t    n               f
# 8        p         x           y         e       f    f               f
# 9        p         x           s         g       t    f               f
# 10       p         x           s         n       f    y               f
# 11       p         x           f         y       f    f               f
# ...
